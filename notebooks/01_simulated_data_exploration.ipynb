# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load simulated data
df = pd.read_csv("../data/simulated_wind_farm_scada.csv")

# Preview the data
df.head()
# Out:
#              timestamp turbine_id  true_wind_speed_ms  nacelle_wind_speed_ms  \
# 0  2025-01-01 00:00:00        T01               8.964                  9.049
# 1  2025-01-01 00:10:00        T01               8.487                  8.731
# 2  2025-01-01 00:20:00        T01               8.689                  8.923
# 3  2025-01-01 00:30:00        T01               9.180                  8.770
# 4  2025-01-01 00:40:00        T01               9.043                  8.433
#
#    wind_direction_deg  temperature_c  pressure_hpa  air_density_kgm3  \
# 0               233.7          11.04        848.94            1.0407
# 1               231.7           9.35        846.21            1.0435
# 2               229.4           8.70        838.43            1.0363
# 3               231.3           5.64        843.56            1.0541
# 4               226.4           4.33        839.87            1.0544
#
#    turbulence_intensity  power_kw  rotor_speed_rpm  blade_pitch_deg  \
# ...
